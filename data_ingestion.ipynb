# %%
catalog_name = "26100355-pa2"
base_path = f"/Volumes/{catalog_name}/bronze/temp"

flight_landing_zone_part2 = f"{base_path}/flight_landing_zone_part2"
cdc_zone_part2 = f"{base_path}/cdc_zone_part2"
